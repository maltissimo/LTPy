# %%
from Hardware.Source import Laser
from Hardware.obis_commands import *
from Communication.MCL import *

# %%
source= Laser()
source.op_mode
# Out:
# ''

# %%
source.serialmessage(isSYSTFAULT)
# Out:
# 0.01699
# 0.01700
# 0.09204
# system_output: 0.01699
# Set power level: 0.01698
# difference output - pow_level:  1.0000000000003062e-05
# Power stabilized!
# setting back the laser to constant current
# CWC
# 0.01699
# 0.09204

# %%
source.serialmessage("SYSTem:NOISE?")
# Out:
# 0.01999
# 0.09642

# %%
source.serialmessage("SOURce:TEMPerature:DIODe?")
# Out:
# CWC
# 0.08951

# %%
source.serialmessage("SOURce:TEMPerature:BASeplate?")
# Out:
# '21.7C'

# %%
source.serialmessage("SOURce:AM:SOURce?")
# Out:
# 'CWC'

# %%
source.serialmessage("SOURce:POWer:LIMit:HIGH?")
# Out:
# '0.05500'

# %%
source.serialmessage("SOUR:POW:CURR?")
# Out:
# '0.08179'

# %%
source.serialmessage(isSYSTSTATUS)
# Out:
# '00001086'

# %%
source.serialmessage(isSYSTINTLOCK)
# Out:
# 'ON'

# %%
source.serialmessage(LASOPMODEINTCW+" CWC")
# Out:
# ''

# %%
source.serialmessage(LASOPMODEINTCW+" CWP")
# Out:
# ''

# %%
source.serialmessage("SYSTem:DIODe:HOURs?")
# Out:
# '11970.05'

# %%
source.serialmessage("SOURce:POWer:CURRent?")
# Out:
# '0.11106'

# %%
source.serialmessage("SOURce:CURRent:LIMit:HIGH?")
# Out:
# '0.19452'

# %%
source.serialmessage("SYSTem:NOISE?")
# Out:
# '0'

# %%
source.serialmessage("SOURce:TEMPerature:DSETpoint?")
# Out:
# '25.0C'
